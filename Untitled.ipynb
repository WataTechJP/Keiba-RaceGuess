# %%
import os
import sys
import django

# Djangoプロジェクトのパスを追加
sys.path.append('/Users/macow/Private/keiba_battle')

# Django設定を指定
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'keiba_battle.settings')

# Djangoを初期化
django.setup()

print("Django setup complete!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import os
#       2 import sys
# ----> 3 import django
#       5 # Djangoプロジェクトのパスを追加
#       6 sys.path.append('/Users/macow/Private/keiba_battle')
#
# ModuleNotFoundError: No module named 'django'
